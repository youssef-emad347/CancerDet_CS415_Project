# %%
import numpy as np
import pandas as pd
import joblib
from tensorflow.keras.models import load_model

# %%
# 1. SETUP: Choose which model you are testing
# ====================================================
# Change these filenames for Lung or Breast models!
MODEL_FILE = 'Breast_Cancer.keras'
SCALER_FILE = 'Breast_Cancer_scaler.pkl'
THRESHOLD = 0.2  # The threshold we decided on (0.3 for Colon)

# %%
# 2. LOAD THE BRAIN & THE TRANSLATOR
# ====================================================
print(f"⏳ Loading {MODEL_FILE}...")
model = load_model(MODEL_FILE)
scaler = joblib.load(SCALER_FILE)
print("✅ Model & Scaler loaded successfully!")
# Out:
# ⏳ Loading Breast_Cancer.keras...
# ✅ Model & Scaler loaded successfully!
